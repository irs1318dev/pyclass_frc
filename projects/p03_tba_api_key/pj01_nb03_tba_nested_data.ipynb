# %% [markdown]
# [Table of Contents](../index.ipynb)

# %% [markdown]
# # Project 1: Analyzing Blue Alliance Data with Python
# # Notebook 3: Creating Datraframes from Nested Data

# %% [markdown]
# ## I. Preparations
# ### A. Other Notebooks in Pyclass FRC
# 1. Get a *Blue Alliance* API authorization key. See [See Instructions here](../../procedures/pc03_tba_api_key/pc03_tba_api_key.ipynb).
# 2. Review [session 07 on Hypertext Transfer Protocol](../../sessions/s07_http/s07_http.ipynb)
# 3. Review [Analyzing Blue Alliance Data with Pyton - Notebook 1](pj01_nb01_tba_http.ipynb)
# 4. Review [Analyzing Blue Alliance Data with Pyton - Notebook 2](pj01_nb02_tba_flat_data.ipynb)
#
# ### B. Official Python Documentation
# This notebook brings together many different Python techniques. These links to the official Python documentation may be helpful when working through this notebook.
# 1. [List comprehensions](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions)
# 2. [Python dictionaries, including dictionary comprehensions](https://docs.python.org/3/tutorial/datastructures.html#dictionaries)
# 3. [Built-in `filter()` function](https://docs.python.org/3/library/functions.html#filter).
# 4. [Dictionary's `items()` method](https://docs.python.org/3/library/stdtypes.html?highlight=items#dict.items)
# 5. [Built-in `isinstance()` function](https://docs.python.org/3/library/functions.html#isinstance)
# 6. [Lamda Expressions](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions)
# 7. [PEP 448 on Dictionary Unpacking](https://www.python.org/dev/peps/pep-0448/)
# 8. [Built in `enumerate()` function](https://docs.python.org/3/library/functions.html#enumerate)
# 9. [Python f strings](https://realpython.com/python-f-strings/#f-strings-a-new-and-improved-way-to-format-strings-in-python).
#
# ### C. Package Imports

# %%
import datetime
import json
import pickle

import pandas as pd

# %% [markdown]
# ### D. Load JSON Data

# %%
with open('matches.json', 'r') as j_file:
    matches = json.load(j_file)

with open('districts.json', 'rb') as p_file:
    districts = json.load(p_file)

# %% [markdown]
# ## II. Overview
# In this notebook we will create a flat (well, ... almost flat) dataframe from highly nested JSON data that contains detailed FRC match scores.
# * Our dataframe will have two rows per match, one for each alliance.
# * There will be an *alliance* column that specifies whether the row is for the blue or red alliance.
# * The dataframe will have three columns that identify the teams that compete in the match, one column for each operator station.
#
# In prior notebooks, we determined that the matches JSON data consists of a list of dictionaries, with one dictionary for every match in the FRC competition. Review the data for the first two matches below:

# %%
matches[0:2]
# Out:
# [{'actual_time': 1583104716,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 136,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc2930', 'frc2976', 'frc4918']},
#    'red': {'dq_team_keys': [],
#     'score': 148,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4911', 'frc2910', 'frc4173']}},
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m1',
#   'match_number': 1,
#   'post_result_time': 1583105046,
#   'predicted_time': 1583104822,
#   'score_breakdown': {'blue': {'adjustPoints': 0,
#     'autoCellPoints': 40,
#     'autoCellsBottom': 0,
#     'autoCellsInner': 2,
#     'autoCellsOuter': 7,
#     'autoInitLinePoints': 15,
#     'autoPoints': 55,
#     'controlPanelPoints': 0,
#     'endgamePoints': 55,
#     'endgameRobot1': 'Hang',
#     'endgameRobot2': 'Hang',
#     'endgameRobot3': 'Park',
#     'endgameRungIsLevel': 'NotLevel',
#     'foulCount': 0,
#     'foulPoints': 0,
#     'initLineRobot1': 'Exited',
#     'initLineRobot2': 'Exited',
#     'initLineRobot3': 'Exited',
#     'rp': 0,
#     'shieldEnergizedRankingPoint': False,
#     'shieldOperationalRankingPoint': False,
#     'stage1Activated': True,
#     'stage2Activated': False,
#     'stage3Activated': False,
#     'stage3TargetColor': 'Unknown',
#     'tba_numRobotsHanging': 2,
#     'tba_shieldEnergizedRankingPointFromFoul': False,
#     'techFoulCount': 0,
#     'teleopCellPoints': 26,
#     'teleopCellsBottom': 0,
#     'teleopCellsInner': 0,
#     'teleopCellsOuter': 13,
#     'teleopPoints': 81,
#     'totalPoints': 136},
#    'red': {'adjustPoints': 0,
#     'autoCellPoints': 32,
#     'autoCellsBottom': 0,
#     'autoCellsInner': 0,
#     'autoCellsOuter': 8,
#     'autoInitLinePoints': 15,
#     'autoPoints': 47,
#     'controlPanelPoints': 0,
#     'endgamePoints': 45,
#     'endgameRobot1': 'Park',
#     'endgameRobot2': 'Hang',
#     'endgameRobot3': 'None',
#     'endgameRungIsLevel': 'IsLevel',
#     'foulCount': 0,
#     'foulPoints': 0,
#     'initLineRobot1': 'Exited',
#     'initLineRobot2': 'Exited',
#     'initLineRobot3': 'Exited',
#     'rp': 0,
#     'shieldEnergizedRankingPoint': False,
#     'shieldOperationalRankingPoint': False,
#     'stage1Activated': True,
#     'stage2Activated': False,
#     'stage3Activated': False,
#     'stage3TargetColor': 'Unknown',
#     'tba_numRobotsHanging': 1,
#     'tba_shieldEnergizedRankingPointFromFoul': False,
#     'techFoulCount': 0,
#     'teleopCellPoints': 56,
#     'teleopCellsBottom': 0,
#     'teleopCellsInner': 4,
#     'teleopCellsOuter': 22,
#     'teleopPoints': 101,
#     'totalPoints': 148}},
#   'set_number': 1,
#   'time': 1583103960,
#   'videos': [{'key': 'QiegqWDKHOQ', 'type': 'youtube'},
#    {'key': 'tijqefvzxIs', 'type': 'youtube'},
#    {'key': '26XinRoNxf8', 'type': 'youtube'}],
#   'winning_alliance': 'red'},
#  {'actual_time': 1583106972,
#   'alliances': {'blue': {'dq_team_keys': [],
#     'score': 137,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc2930', 'frc2976', 'frc4918']},
#    'red': {'dq_team_keys': [],
#     'score': 163,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4911', 'frc2910', 'frc4173']}},
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m2',
#   'match_number': 2,
#   'post_result_time': 1583107173,
#   'predicted_time': 1583107040,
#   'score_breakdown': {'blue': {'adjustPoints': 0,
#     'autoCellPoints': 38,
#     'autoCellsBottom': 0,
#     'autoCellsInner': 1,
#     'autoCellsOuter': 8,
#     'autoInitLinePoints': 15,
#     'autoPoints': 53,
#     'controlPanelPoints': 0,
#     'endgamePoints': 50,
#     'endgameRobot1': 'None',
#     'endgameRobot2': 'Hang',
#     'endgameRobot3': 'Hang',
#     'endgameRungIsLevel': 'NotLevel',
#     'foulCount': 0,
#     'foulPoints': 0,
#     'initLineRobot1': 'Exited',
#     'initLineRobot2': 'Exited',
#     'initLineRobot3': 'Exited',
#     'rp': 0,
#     'shieldEnergizedRankingPoint': False,
#     'shieldOperationalRankingPoint': False,
#     'stage1Activated': True,
#     'stage2Activated': False,
#     'stage3Activated': False,
#     'stage3TargetColor': 'Unknown',
#     'tba_numRobotsHanging': 2,
#     'tba_shieldEnergizedRankingPointFromFoul': False,
#     'techFoulCount': 3,
#     'teleopCellPoints': 34,
#     'teleopCellsBottom': 0,
#     'teleopCellsInner': 0,
#     'teleopCellsOuter': 17,
#     'teleopPoints': 84,
#     'totalPoints': 137},
#    'red': {'adjustPoints': 0,
#     'autoCellPoints': 20,
#     'autoCellsBottom': 0,
#     'autoCellsInner': 0,
#     'autoCellsOuter': 5,
#     'autoInitLinePoints': 15,
#     'autoPoints': 35,
#     'controlPanelPoints': 0,
#     'endgamePoints': 40,
#     'endgameRobot1': 'None',
#     'endgameRobot2': 'Hang',
#     'endgameRobot3': 'None',
#     'endgameRungIsLevel': 'IsLevel',
#     'foulCount': 0,
#     'foulPoints': 45,
#     'initLineRobot1': 'Exited',
#     'initLineRobot2': 'Exited',
#     'initLineRobot3': 'Exited',
#     'rp': 0,
#     'shieldEnergizedRankingPoint': False,
#     'shieldOperationalRankingPoint': False,
#     'stage1Activated': True,
#     'stage2Activated': False,
#     'stage3Activated': False,
#     'stage3TargetColor': 'Unknown',
#     'tba_numRobotsHanging': 1,
#     'tba_shieldEnergizedRankingPointFromFoul': False,
#     'techFoulCount': 0,
#     'teleopCellPoints': 43,
#     'teleopCellsBottom': 0,
#     'teleopCellsInner': 3,
#     'teleopCellsOuter': 17,
#     'teleopPoints': 83,
#     'totalPoints': 163}},
#   'set_number': 1,
#   'time': 1583104380,
#   'videos': [{'key': '8UWIqYfIj_Q', 'type': 'youtube'},
#    {'key': 'lQdwow-OjpU', 'type': 'youtube'}],
#   'winning_alliance': 'red'}]

# %% [markdown]
# ## III. Lambda Functions and the Built-in `filter()` Function
# Many of the top-level keys in each dictionary contain atomic data. Each of these keys can be converted into a database column with a simple list comprehension.

# %%
top_level_keys = [{'actual_time': mtch['actual_time'], 'comp_level': mtch['comp_level'],
                  'event_key': mtch['event_key']} for mtch in matches]
top_level_keys[:3]
# Out:
# [{'actual_time': 1583104716, 'comp_level': 'f', 'event_key': '2020wasno'},
#  {'actual_time': 1583106972, 'comp_level': 'f', 'event_key': '2020wasno'},
#  {'actual_time': 1583096632, 'comp_level': 'qf', 'event_key': '2020wasno'}]

# %%
pd.DataFrame(top_level_keys).head(3)
# Out:
#    actual_time comp_level  event_key
# 0   1583104716          f  2020wasno
# 1   1583106972          f  2020wasno
# 2   1583096632         qf  2020wasno

# %% [markdown]
# There are 13 top-level dictionary keys, and with this approach each key needs to be typed twice. I got tired of typing the keys after typing only three of them. There are many drawbacks to this approach.
# * It's tiring.
# * It's prone to errors. There are 26 opportunities to type the name of the key incorrectly.
# * The code will break if TBA-API changes one of the keys.
#
# Fortunately, there is a better way. Python has a built-in function called `filter()` that can be used to extract only the dictionary keys that we want.3. The [`filter()` documentation is here](https://docs.python.org/3/library/functions.html#filter).
#
# The `filter()` function takes two arguments. The first argument passed to filter is a function that itself takes one argument and returns either `True` or `False`. The second argument is an iterable object like a Python list. `filter()` will pass every element of the list to the function in the first argument, and will return only those elements for wich the function returns True. That probably doesn't make much sense, but an example should clarify the situation.
#
# We will first consider the second argument to `filter()`. We will pass a top-level dictionary to `filter()` as the second argument, but we first must convert the dictionary to a list of sorts using the dictionary's [`items()` method](https://docs.python.org/3/library/stdtypes.html?highlight=items#dict.items).

# %%
top_level_match_dictionary = matches[0]
list(top_level_match_dictionary.items())[:5]
# Out:
# [('actual_time', 1583104716),
#  ('alliances',
#   {'blue': {'dq_team_keys': [],
#     'score': 136,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc2930', 'frc2976', 'frc4918']},
#    'red': {'dq_team_keys': [],
#     'score': 148,
#     'surrogate_team_keys': [],
#     'team_keys': ['frc4911', 'frc2910', 'frc4173']}}),
#  ('comp_level', 'f'),
#  ('event_key', '2020wasno'),
#  ('key', '2020wasno_f1m1')]

# %% [markdown]
# The `items()` method allows us to convert a dictionary's key-value pairs into a list of tuple objects, with the dictionary key as the first element of the tuple and the dictionary value as the second element.
#
# Next, we will take advantage of the fact that all non-atomic values in the top-level matches dictionaries are lists or are themselves dictionaries. We will write a custom function that takes a single key-value tuple, as returned by `items()` above, and returns True if the second element of the tuple is anything other than a list or dictionary. Otherwise the function will False.

# %%
def is_not_dict_or_list(tpl):
    return not isinstance(tpl[1], (dict, list))

# %% [markdown]
# The [built-in `isinstance()` function](https://docs.python.org/3/library/functions.html#isinstance) returns True if the second element of the tuple is a list or dictionary. The `not` keyword reverses the result so `is_not_dict_or_list()` will return True of the second tuple element is anything *other than* a list or dictionary.
#
# Now let's put this all together:

# %%
dict(filter(is_not_dict_or_list, top_level_match_dictionary.items()))
# Out:
# {'actual_time': 1583104716,
#  'comp_level': 'f',
#  'event_key': '2020wasno',
#  'key': '2020wasno_f1m1',
#  'match_number': 1,
#  'post_result_time': 1583105046,
#  'predicted_time': 1583104822,
#  'set_number': 1,
#  'time': 1583103960,
#  'winning_alliance': 'red'}

# %% [markdown]
# Voila. We have filtered the top-level dictionary such that it contains only atomic values. And we did it without too much code. But we can do better.
#
# We can define the custom filtering function within the `filter()` function call using a [lamda expression](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions).

# %%
dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)),
                                       top_level_match_dictionary.items()))
# Out:
# {'actual_time': 1583104716,
#  'comp_level': 'f',
#  'event_key': '2020wasno',
#  'key': '2020wasno_f1m1',
#  'match_number': 1,
#  'post_result_time': 1583105046,
#  'predicted_time': 1583104822,
#  'set_number': 1,
#  'time': 1583103960,
#  'winning_alliance': 'red'}

# %% [markdown]
# `lambda` is a Python keyword that allows us to create short anonymous functions. Consider the lambda expression we just used:
# ```Python
# lambda tpl: not isinstance(tpl[1], (dict, list))
# ```
#
# The `lambda` keyword tells Python to create a function from the statement that follows. The items between the `lambda` keyword and the colon are the arguments to the function. Our lambda function takes only one argument, but lambda expressions can take multiple arguments separated by commas. The statement after the colon will be returned by the lambda function.Lambda functions have a few advantages:
# * They improve code maintainability because everything needed for the statement to work is included in the statement itself. We don't have to worry that the `top_level_match_dictionary()` function will get deleted or otherwise messed up.
# * They improve readability in the sense that no cross referencing to a separate function is needed to understand what the statement does.
# * The programmer does not have to think up a name for a function that is only going to get used in one place.
#
# Lambda functions can only consist of a single statement. For some readers of this code, lambda functions can degrade readability in the sense that they result in a lot of functionality being packed into just one line. But for readers who are proficient with the lambda syntax, this disadvantage is minor.
#
# Lamda functions are not unique to Python. Many other languages, such as Java and C++ also allow similar anonymous functions, although they don't use the `lambda` keyword.
#
# We passed the filter-lambda statement to the built-in `dict()` function to convert the output of `filter()` to a dictionary object.
#
# Next we'll place the dict-filter-lambda statement in a list comprehension.

# %%
match_data_list = [dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items()))
                   for mtch in matches]
match_data_list
# Out:
# [{'actual_time': 1583104716,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m1',
#   'match_number': 1,
#   'post_result_time': 1583105046,
#   'predicted_time': 1583104822,
#   'set_number': 1,
#   'time': 1583103960,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583106972,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m2',
#   'match_number': 2,
#   'post_result_time': 1583107173,
#   'predicted_time': 1583107040,
#   'set_number': 1,
#   'time': 1583104380,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583096632,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m1',
#   'match_number': 1,
#   'post_result_time': 1583096863,
#   'predicted_time': 1583096645,
#   'set_number': 1,
#   'time': 1583096400,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583098723,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m2',
#   'match_number': 2,
#   'post_result_time': 1583098931,
#   'predicted_time': 1583098747,
#   'set_number': 1,
#   'time': 1583098080,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583097215,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf2m1',
#   'match_number': 1,
#   'post_result_time': 1583097388,
#   'predicted_time': 1583097192,
#   'set_number': 2,
#   'time': 1583096820,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583099250,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf2m2',
#   'match_number': 2,
#   'post_result_time': 1583099438,
#   'predicted_time': 1583099225,
#   'set_number': 2,
#   'time': 1583098500,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583097622,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf3m1',
#   'match_number': 1,
#   'post_result_time': 1583097827,
#   'predicted_time': 1583097648,
#   'set_number': 3,
#   'time': 1583097240,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583100029,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf3m2',
#   'match_number': 2,
#   'post_result_time': 1583100206,
#   'predicted_time': 1583100005,
#   'set_number': 3,
#   'time': 1583098920,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583101227,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf3m3',
#   'match_number': 3,
#   'post_result_time': 1583101472,
#   'predicted_time': 1583101280,
#   'set_number': 3,
#   'time': 1583100600,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583098300,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf4m1',
#   'match_number': 1,
#   'post_result_time': 1583098546,
#   'predicted_time': 1583098340,
#   'set_number': 4,
#   'time': 1583097660,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583100440,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf4m2',
#   'match_number': 2,
#   'post_result_time': 1583100645,
#   'predicted_time': 1583100454,
#   'set_number': 4,
#   'time': 1583099340,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583003064,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm1',
#   'match_number': 1,
#   'post_result_time': 1583003253,
#   'predicted_time': 1583003164,
#   'set_number': 1,
#   'time': 1583002800,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583008752,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm10',
#   'match_number': 10,
#   'post_result_time': 1583009031,
#   'predicted_time': 1583008805,
#   'set_number': 1,
#   'time': 1583007540,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583009233,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm11',
#   'match_number': 11,
#   'post_result_time': 1583009433,
#   'predicted_time': 1583009404,
#   'set_number': 1,
#   'time': 1583008020,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583009807,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm12',
#   'match_number': 12,
#   'post_result_time': 1583010026,
#   'predicted_time': 1583009885,
#   'set_number': 1,
#   'time': 1583008500,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583010446,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm13',
#   'match_number': 13,
#   'post_result_time': 1583010645,
#   'predicted_time': 1583010484,
#   'set_number': 1,
#   'time': 1583008980,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583011069,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm14',
#   'match_number': 14,
#   'post_result_time': 1583011248,
#   'predicted_time': 1583011145,
#   'set_number': 1,
#   'time': 1583009460,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583014060,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm15',
#   'match_number': 15,
#   'post_result_time': 1583014262,
#   'predicted_time': 1583014204,
#   'set_number': 1,
#   'time': 1583013600,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583014520,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm16',
#   'match_number': 16,
#   'post_result_time': 1583014707,
#   'predicted_time': 1583014617,
#   'set_number': 1,
#   'time': 1583014020,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583014940,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm17',
#   'match_number': 17,
#   'post_result_time': 1583015143,
#   'predicted_time': 1583015072,
#   'set_number': 1,
#   'time': 1583014440,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583015366,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm18',
#   'match_number': 18,
#   'post_result_time': 1583015592,
#   'predicted_time': 1583015524,
#   'set_number': 1,
#   'time': 1583014860,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583015857,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm19',
#   'match_number': 19,
#   'post_result_time': 1583016074,
#   'predicted_time': 1583015912,
#   'set_number': 1,
#   'time': 1583015280,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583003812,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm2',
#   'match_number': 2,
#   'post_result_time': 1583004126,
#   'predicted_time': 1583004064,
#   'set_number': 1,
#   'time': 1583003340,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583016304,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm20',
#   'match_number': 20,
#   'post_result_time': 1583016642,
#   'predicted_time': 1583016424,
#   'set_number': 1,
#   'time': 1583015700,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583016833,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm21',
#   'match_number': 21,
#   'post_result_time': 1583017157,
#   'predicted_time': 1583016903,
#   'set_number': 1,
#   'time': 1583016120,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583017343,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm22',
#   'match_number': 22,
#   'post_result_time': 1583017629,
#   'predicted_time': 1583017503,
#   'set_number': 1,
#   'time': 1583016540,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583017796,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm23',
#   'match_number': 23,
#   'post_result_time': 1583018080,
#   'predicted_time': 1583017924,
#   'set_number': 1,
#   'time': 1583016960,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583018197,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm24',
#   'match_number': 24,
#   'post_result_time': 1583018409,
#   'predicted_time': 1583018343,
#   'set_number': 1,
#   'time': 1583017380,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583018601,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm25',
#   'match_number': 25,
#   'post_result_time': 1583018899,
#   'predicted_time': 1583018705,
#   'set_number': 1,
#   'time': 1583017800,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583019188,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm26',
#   'match_number': 26,
#   'post_result_time': 1583019393,
#   'predicted_time': 1583019304,
#   'set_number': 1,
#   'time': 1583018220,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583019739,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm27',
#   'match_number': 27,
#   'post_result_time': 1583019987,
#   'predicted_time': 1583019904,
#   'set_number': 1,
#   'time': 1583018640,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583020125,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm28',
#   'match_number': 28,
#   'post_result_time': 1583020464,
#   'predicted_time': 1583020385,
#   'set_number': 1,
#   'time': 1583019060,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583020600,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm29',
#   'match_number': 29,
#   'post_result_time': 1583020828,
#   'predicted_time': 1583020749,
#   'set_number': 1,
#   'time': 1583019480,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583004450,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm3',
#   'match_number': 3,
#   'post_result_time': 1583004658,
#   'predicted_time': 1583004604,
#   'set_number': 1,
#   'time': 1583003880,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583021165,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm30',
#   'match_number': 30,
#   'post_result_time': 1583021479,
#   'predicted_time': 1583021404,
#   'set_number': 1,
#   'time': 1583019900,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583021602,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm31',
#   'match_number': 31,
#   'post_result_time': 1583021883,
#   'predicted_time': 1583021764,
#   'set_number': 1,
#   'time': 1583020320,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583022569,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm32',
#   'match_number': 32,
#   'post_result_time': 1583022861,
#   'predicted_time': 1583022724,
#   'set_number': 1,
#   'time': 1583021700,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583023138,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm33',
#   'match_number': 33,
#   'post_result_time': 1583023433,
#   'predicted_time': 1583023325,
#   'set_number': 1,
#   'time': 1583022120,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583023626,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm34',
#   'match_number': 34,
#   'post_result_time': 1583023871,
#   'predicted_time': 1583023683,
#   'set_number': 1,
#   'time': 1583022540,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583024132,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm35',
#   'match_number': 35,
#   'post_result_time': 1583024341,
#   'predicted_time': 1583024104,
#   'set_number': 1,
#   'time': 1583022960,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583024571,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm36',
#   'match_number': 36,
#   'post_result_time': 1583024837,
#   'predicted_time': 1583024601,
#   'set_number': 1,
#   'time': 1583023380,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583025045,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm37',
#   'match_number': 37,
#   'post_result_time': 1583025263,
#   'predicted_time': 1583025065,
#   'set_number': 1,
#   'time': 1583023800,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583025575,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm38',
#   'match_number': 38,
#   'post_result_time': 1583025754,
#   'predicted_time': 1583025604,
#   'set_number': 1,
#   'time': 1583024220,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583026044,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm39',
#   'match_number': 39,
#   'post_result_time': 1583026347,
#   'predicted_time': 1583026204,
#   'set_number': 1,
#   'time': 1583024640,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583035649,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm4',
#   'match_number': 4,
#   'post_result_time': 1583035846,
#   'predicted_time': 1583005324,
#   'set_number': 1,
#   'time': 1583004420,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583026451,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm40',
#   'match_number': 40,
#   'post_result_time': 1583026630,
#   'predicted_time': 1583026564,
#   'set_number': 1,
#   'time': 1583025060,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583026880,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm41',
#   'match_number': 41,
#   'post_result_time': 1583027121,
#   'predicted_time': 1583026985,
#   'set_number': 1,
#   'time': 1583025480,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583027331,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm42',
#   'match_number': 42,
#   'post_result_time': 1583027512,
#   'predicted_time': 1583027464,
#   'set_number': 1,
#   'time': 1583025900,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583027881,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm43',
#   'match_number': 43,
#   'post_result_time': 1583028100,
#   'predicted_time': 1583028004,
#   'set_number': 1,
#   'time': 1583026320,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583028292,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm44',
#   'match_number': 44,
#   'post_result_time': 1583028549,
#   'predicted_time': 1583028382,
#   'set_number': 1,
#   'time': 1583026740,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583028814,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm45',
#   'match_number': 45,
#   'post_result_time': 1583028998,
#   'predicted_time': 1583028920,
#   'set_number': 1,
#   'time': 1583027160,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583029256,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm46',
#   'match_number': 46,
#   'post_result_time': 1583029512,
#   'predicted_time': 1583029400,
#   'set_number': 1,
#   'time': 1583027580,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583029701,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm47',
#   'match_number': 47,
#   'post_result_time': 1583029896,
#   'predicted_time': 1583029820,
#   'set_number': 1,
#   'time': 1583028000,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583030146,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm48',
#   'match_number': 48,
#   'post_result_time': 1583030333,
#   'predicted_time': 1583030240,
#   'set_number': 1,
#   'time': 1583028420,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583030543,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm49',
#   'match_number': 49,
#   'post_result_time': 1583030780,
#   'predicted_time': 1583030660,
#   'set_number': 1,
#   'time': 1583028840,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583005608,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm5',
#   'match_number': 5,
#   'post_result_time': 1583005779,
#   'predicted_time': 1583005596,
#   'set_number': 1,
#   'time': 1583004960,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583030993,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm50',
#   'match_number': 50,
#   'post_result_time': 1583031171,
#   'predicted_time': 1583031080,
#   'set_number': 1,
#   'time': 1583029260,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583031399,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm51',
#   'match_number': 51,
#   'post_result_time': 1583031583,
#   'predicted_time': 1583031440,
#   'set_number': 1,
#   'time': 1583029680,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583031842,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm52',
#   'match_number': 52,
#   'post_result_time': 1583032023,
#   'predicted_time': 1583031862,
#   'set_number': 1,
#   'time': 1583030100,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583032310,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm53',
#   'match_number': 53,
#   'post_result_time': 1583032546,
#   'predicted_time': 1583032340,
#   'set_number': 1,
#   'time': 1583030520,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583032744,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm54',
#   'match_number': 54,
#   'post_result_time': 1583032914,
#   'predicted_time': 1583032762,
#   'set_number': 1,
#   'time': 1583030940,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583033324,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm55',
#   'match_number': 55,
#   'post_result_time': 1583033497,
#   'predicted_time': 1583033300,
#   'set_number': 1,
#   'time': 1583031360,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583033705,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm56',
#   'match_number': 56,
#   'post_result_time': 1583033882,
#   'predicted_time': 1583033764,
#   'set_number': 1,
#   'time': 1583031780,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583034072,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm57',
#   'match_number': 57,
#   'post_result_time': 1583034245,
#   'predicted_time': 1583034144,
#   'set_number': 1,
#   'time': 1583032200,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583034489,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm58',
#   'match_number': 58,
#   'post_result_time': 1583034671,
#   'predicted_time': 1583034559,
#   'set_number': 1,
#   'time': 1583032620,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583034942,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm59',
#   'match_number': 59,
#   'post_result_time': 1583035159,
#   'predicted_time': 1583034980,
#   'set_number': 1,
#   'time': 1583033040,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583006302,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm6',
#   'match_number': 6,
#   'post_result_time': 1583006627,
#   'predicted_time': 1583006524,
#   'set_number': 1,
#   'time': 1583005500,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583084118,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm60',
#   'match_number': 60,
#   'post_result_time': 1583084306,
#   'predicted_time': 1583084231,
#   'set_number': 1,
#   'time': 1583083800,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583084582,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm61',
#   'match_number': 61,
#   'post_result_time': 1583084787,
#   'predicted_time': 1583084644,
#   'set_number': 1,
#   'time': 1583084340,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583084991,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm62',
#   'match_number': 62,
#   'post_result_time': 1583085183,
#   'predicted_time': 1583085068,
#   'set_number': 1,
#   'time': 1583084880,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583085401,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm63',
#   'match_number': 63,
#   'post_result_time': 1583085586,
#   'predicted_time': 1583085452,
#   'set_number': 1,
#   'time': 1583085300,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583086025,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm64',
#   'match_number': 64,
#   'post_result_time': 1583086198,
#   'predicted_time': 1583086148,
#   'set_number': 1,
#   'time': 1583085720,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583086410,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm65',
#   'match_number': 65,
#   'post_result_time': 1583086587,
#   'predicted_time': 1583086504,
#   'set_number': 1,
#   'time': 1583086140,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583087028,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm66',
#   'match_number': 66,
#   'post_result_time': 1583087217,
#   'predicted_time': 1583087060,
#   'set_number': 1,
#   'time': 1583086560,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583087449,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm67',
#   'match_number': 67,
#   'post_result_time': 1583087732,
#   'predicted_time': 1583087651,
#   'set_number': 1,
#   'time': 1583086980,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583087895,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm68',
#   'match_number': 68,
#   'post_result_time': 1583088152,
#   'predicted_time': 1583088020,
#   'set_number': 1,
#   'time': 1583087400,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583088388,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm69',
#   'match_number': 69,
#   'post_result_time': 1583088570,
#   'predicted_time': 1583088365,
#   'set_number': 1,
#   'time': 1583087820,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583006892,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm7',
#   'match_number': 7,
#   'post_result_time': 1583007197,
#   'predicted_time': 1583007004,
#   'set_number': 1,
#   'time': 1583006040,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583088948,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm70',
#   'match_number': 70,
#   'post_result_time': 1583089153,
#   'predicted_time': 1583089101,
#   'set_number': 1,
#   'time': 1583088240,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583089474,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm71',
#   'match_number': 71,
#   'post_result_time': 1583089644,
#   'predicted_time': 1583089460,
#   'set_number': 1,
#   'time': 1583088660,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583089866,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm72',
#   'match_number': 72,
#   'post_result_time': 1583090055,
#   'predicted_time': 1583089917,
#   'set_number': 1,
#   'time': 1583089080,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583090297,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm73',
#   'match_number': 73,
#   'post_result_time': 1583090478,
#   'predicted_time': 1583090408,
#   'set_number': 1,
#   'time': 1583089500,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583091260,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm74',
#   'match_number': 74,
#   'post_result_time': 1583091449,
#   'predicted_time': 1583094964,
#   'set_number': 1,
#   'time': 1583089920,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583007674,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm8',
#   'match_number': 8,
#   'post_result_time': 1583007902,
#   'predicted_time': 1583007724,
#   'set_number': 1,
#   'time': 1583006580,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583008167,
#   'comp_level': 'qm',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qm9',
#   'match_number': 9,
#   'post_result_time': 1583008373,
#   'predicted_time': 1583008328,
#   'set_number': 1,
#   'time': 1583007060,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583101803,
#   'comp_level': 'sf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_sf1m1',
#   'match_number': 1,
#   'post_result_time': 1583101992,
#   'predicted_time': 1583101804,
#   'set_number': 1,
#   'time': 1583101440,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583102858,
#   'comp_level': 'sf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_sf1m2',
#   'match_number': 2,
#   'post_result_time': 1583103043,
#   'predicted_time': 1583102848,
#   'set_number': 1,
#   'time': 1583102280,
#   'winning_alliance': 'red'},
#  {'actual_time': 1583102423,
#   'comp_level': 'sf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_sf2m1',
#   'match_number': 1,
#   'post_result_time': 1583102619,
#   'predicted_time': 1583102423,
#   'set_number': 2,
#   'time': 1583101860,
#   'winning_alliance': 'blue'},
#  {'actual_time': 1583103375,
#   'comp_level': 'sf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_sf2m2',
#   'match_number': 2,
#   'post_result_time': 1583103818,
#   'predicted_time': 1583103620,
#   'set_number': 2,
#   'time': 1583102700,
#   'winning_alliance': 'blue'}]

# %% [markdown]
# And now we'll create a dataframe from the list.

# %%
pd.DataFrame(match_data_list).head()
# Out:
#    actual_time comp_level  event_key              key  match_number  \
# 0   1583104716          f  2020wasno   2020wasno_f1m1             1
# 1   1583106972          f  2020wasno   2020wasno_f1m2             2
# 2   1583096632         qf  2020wasno  2020wasno_qf1m1             1
# 3   1583098723         qf  2020wasno  2020wasno_qf1m2             2
# 4   1583097215         qf  2020wasno  2020wasno_qf2m1             1
#
#    post_result_time  predicted_time  set_number        time winning_alliance
# 0        1583105046      1583104822           1  1583103960              red
# 1        1583107173      1583107040           1  1583104380              red
# 2        1583096863      1583096645           1  1583096400              red
# 3        1583098931      1583098747           1  1583098080              red
# 4        1583097388      1583097192           2  1583096820             blue

# %% [markdown]
# Very cool.

# %% [markdown]
# ## IV. Dictionary Unpacking
# In the [previous notebook](pj01_nb02_tba_flat_data.ipynb#row_approach) we used a list comprehension to extract the sub-dictionary with the key *score_breakdown* into it's own list.

# %%
blue_rows = [mtch['score_breakdown']['blue'] for mtch in matches]
blue_rows[:5]
# Out:
# [{'adjustPoints': 0,
#   'autoCellPoints': 40,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 2,
#   'autoCellsOuter': 7,
#   'autoInitLinePoints': 15,
#   'autoPoints': 55,
#   'controlPanelPoints': 0,
#   'endgamePoints': 55,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Park',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 26,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 13,
#   'teleopPoints': 81,
#   'totalPoints': 136},
#  {'adjustPoints': 0,
#   'autoCellPoints': 38,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 8,
#   'autoInitLinePoints': 15,
#   'autoPoints': 53,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'None',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 3,
#   'teleopCellPoints': 34,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 17,
#   'teleopPoints': 84,
#   'totalPoints': 137},
#  {'adjustPoints': 0,
#   'autoCellPoints': 20,
#   'autoCellsBottom': 3,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 35,
#   'controlPanelPoints': 0,
#   'endgamePoints': 65,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'None',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 1,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 19,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 1,
#   'teleopCellsOuter': 8,
#   'teleopPoints': 84,
#   'totalPoints': 122},
#  {'adjustPoints': 0,
#   'autoCellPoints': 10,
#   'autoCellsBottom': 1,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 25,
#   'controlPanelPoints': 0,
#   'endgamePoints': 70,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Park',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': False,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 0,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 0,
#   'teleopPoints': 70,
#   'totalPoints': 95},
#  {'adjustPoints': 0,
#   'autoCellPoints': 24,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 6,
#   'autoInitLinePoints': 15,
#   'autoPoints': 39,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'None',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 42,
#   'teleopCellsBottom': 1,
#   'teleopCellsInner': 3,
#   'teleopCellsOuter': 16,
#   'teleopPoints': 92,
#   'totalPoints': 134}]

# %% [markdown]
# We would like to combine the score columns from this list comprehension with the match data columns that we created with the `filter()` function. Just sticking both code snippets into a list comprehension does not work - the following code will result in a syntax error:
# ```Python
# blue_rows = [dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
#              mtch['score_breakdown']['blue']
#              for mtch in matches]
# ```
# The problem is that the expression in a list comprehension befor the `for` keyword is supposed to return a single list element. But the expression in the snippet above is returning *two* dictionaries, and the list comprehension can't figure out what to do with that.
#
# If you are thinking that the list comprehension would work if we enclose both the `mtch['score...` and `dict(filter(lambda...` dictionary expressions in parenthesis to create a tuple, you would be correct.

# %%
tuple_list = [(dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
              mtch['score_breakdown']['blue'])
              for mtch in matches]
tuple_list[:5]
# Out:
# [({'actual_time': 1583104716,
#    'comp_level': 'f',
#    'event_key': '2020wasno',
#    'key': '2020wasno_f1m1',
#    'match_number': 1,
#    'post_result_time': 1583105046,
#    'predicted_time': 1583104822,
#    'set_number': 1,
#    'time': 1583103960,
#    'winning_alliance': 'red'},
#   {'adjustPoints': 0,
#    'autoCellPoints': 40,
#    'autoCellsBottom': 0,
#    'autoCellsInner': 2,
#    'autoCellsOuter': 7,
#    'autoInitLinePoints': 15,
#    'autoPoints': 55,
#    'controlPanelPoints': 0,
#    'endgamePoints': 55,
#    'endgameRobot1': 'Hang',
#    'endgameRobot2': 'Hang',
#    'endgameRobot3': 'Park',
#    'endgameRungIsLevel': 'NotLevel',
#    'foulCount': 0,
#    'foulPoints': 0,
#    'initLineRobot1': 'Exited',
#    'initLineRobot2': 'Exited',
#    'initLineRobot3': 'Exited',
#    'rp': 0,
#    'shieldEnergizedRankingPoint': False,
#    'shieldOperationalRankingPoint': False,
#    'stage1Activated': True,
#    'stage2Activated': False,
#    'stage3Activated': False,
#    'stage3TargetColor': 'Unknown',
#    'tba_numRobotsHanging': 2,
#    'tba_shieldEnergizedRankingPointFromFoul': False,
#    'techFoulCount': 0,
#    'teleopCellPoints': 26,
#    'teleopCellsBottom': 0,
#    'teleopCellsInner': 0,
#    'teleopCellsOuter': 13,
#    'teleopPoints': 81,
#    'totalPoints': 136}),
#  ({'actual_time': 1583106972,
#    'comp_level': 'f',
#    'event_key': '2020wasno',
#    'key': '2020wasno_f1m2',
#    'match_number': 2,
#    'post_result_time': 1583107173,
#    'predicted_time': 1583107040,
#    'set_number': 1,
#    'time': 1583104380,
#    'winning_alliance': 'red'},
#   {'adjustPoints': 0,
#    'autoCellPoints': 38,
#    'autoCellsBottom': 0,
#    'autoCellsInner': 1,
#    'autoCellsOuter': 8,
#    'autoInitLinePoints': 15,
#    'autoPoints': 53,
#    'controlPanelPoints': 0,
#    'endgamePoints': 50,
#    'endgameRobot1': 'None',
#    'endgameRobot2': 'Hang',
#    'endgameRobot3': 'Hang',
#    'endgameRungIsLevel': 'NotLevel',
#    'foulCount': 0,
#    'foulPoints': 0,
#    'initLineRobot1': 'Exited',
#    'initLineRobot2': 'Exited',
#    'initLineRobot3': 'Exited',
#    'rp': 0,
#    'shieldEnergizedRankingPoint': False,
#    'shieldOperationalRankingPoint': False,
#    'stage1Activated': True,
#    'stage2Activated': False,
#    'stage3Activated': False,
#    'stage3TargetColor': 'Unknown',
#    'tba_numRobotsHanging': 2,
#    'tba_shieldEnergizedRankingPointFromFoul': False,
#    'techFoulCount': 3,
#    'teleopCellPoints': 34,
#    'teleopCellsBottom': 0,
#    'teleopCellsInner': 0,
#    'teleopCellsOuter': 17,
#    'teleopPoints': 84,
#    'totalPoints': 137}),
#  ({'actual_time': 1583096632,
#    'comp_level': 'qf',
#    'event_key': '2020wasno',
#    'key': '2020wasno_qf1m1',
#    'match_number': 1,
#    'post_result_time': 1583096863,
#    'predicted_time': 1583096645,
#    'set_number': 1,
#    'time': 1583096400,
#    'winning_alliance': 'red'},
#   {'adjustPoints': 0,
#    'autoCellPoints': 20,
#    'autoCellsBottom': 3,
#    'autoCellsInner': 1,
#    'autoCellsOuter': 2,
#    'autoInitLinePoints': 15,
#    'autoPoints': 35,
#    'controlPanelPoints': 0,
#    'endgamePoints': 65,
#    'endgameRobot1': 'Hang',
#    'endgameRobot2': 'None',
#    'endgameRobot3': 'Hang',
#    'endgameRungIsLevel': 'IsLevel',
#    'foulCount': 1,
#    'foulPoints': 3,
#    'initLineRobot1': 'Exited',
#    'initLineRobot2': 'Exited',
#    'initLineRobot3': 'Exited',
#    'rp': 0,
#    'shieldEnergizedRankingPoint': False,
#    'shieldOperationalRankingPoint': False,
#    'stage1Activated': True,
#    'stage2Activated': False,
#    'stage3Activated': False,
#    'stage3TargetColor': 'Unknown',
#    'tba_numRobotsHanging': 2,
#    'tba_shieldEnergizedRankingPointFromFoul': False,
#    'techFoulCount': 0,
#    'teleopCellPoints': 19,
#    'teleopCellsBottom': 0,
#    'teleopCellsInner': 1,
#    'teleopCellsOuter': 8,
#    'teleopPoints': 84,
#    'totalPoints': 122}),
#  ({'actual_time': 1583098723,
#    'comp_level': 'qf',
#    'event_key': '2020wasno',
#    'key': '2020wasno_qf1m2',
#    'match_number': 2,
#    'post_result_time': 1583098931,
#    'predicted_time': 1583098747,
#    'set_number': 1,
#    'time': 1583098080,
#    'winning_alliance': 'red'},
#   {'adjustPoints': 0,
#    'autoCellPoints': 10,
#    'autoCellsBottom': 1,
#    'autoCellsInner': 0,
#    'autoCellsOuter': 2,
#    'autoInitLinePoints': 15,
#    'autoPoints': 25,
#    'controlPanelPoints': 0,
#    'endgamePoints': 70,
#    'endgameRobot1': 'Hang',
#    'endgameRobot2': 'Park',
#    'endgameRobot3': 'Hang',
#    'endgameRungIsLevel': 'IsLevel',
#    'foulCount': 0,
#    'foulPoints': 0,
#    'initLineRobot1': 'Exited',
#    'initLineRobot2': 'Exited',
#    'initLineRobot3': 'Exited',
#    'rp': 0,
#    'shieldEnergizedRankingPoint': False,
#    'shieldOperationalRankingPoint': False,
#    'stage1Activated': False,
#    'stage2Activated': False,
#    'stage3Activated': False,
#    'stage3TargetColor': 'Unknown',
#    'tba_numRobotsHanging': 2,
#    'tba_shieldEnergizedRankingPointFromFoul': False,
#    'techFoulCount': 0,
#    'teleopCellPoints': 0,
#    'teleopCellsBottom': 0,
#    'teleopCellsInner': 0,
#    'teleopCellsOuter': 0,
#    'teleopPoints': 70,
#    'totalPoints': 95}),
#  ({'actual_time': 1583097215,
#    'comp_level': 'qf',
#    'event_key': '2020wasno',
#    'key': '2020wasno_qf2m1',
#    'match_number': 1,
#    'post_result_time': 1583097388,
#    'predicted_time': 1583097192,
#    'set_number': 2,
#    'time': 1583096820,
#    'winning_alliance': 'blue'},
#   {'adjustPoints': 0,
#    'autoCellPoints': 24,
#    'autoCellsBottom': 0,
#    'autoCellsInner': 0,
#    'autoCellsOuter': 6,
#    'autoInitLinePoints': 15,
#    'autoPoints': 39,
#    'controlPanelPoints': 0,
#    'endgamePoints': 50,
#    'endgameRobot1': 'Hang',
#    'endgameRobot2': 'Hang',
#    'endgameRobot3': 'None',
#    'endgameRungIsLevel': 'NotLevel',
#    'foulCount': 0,
#    'foulPoints': 3,
#    'initLineRobot1': 'Exited',
#    'initLineRobot2': 'Exited',
#    'initLineRobot3': 'Exited',
#    'rp': 0,
#    'shieldEnergizedRankingPoint': False,
#    'shieldOperationalRankingPoint': False,
#    'stage1Activated': True,
#    'stage2Activated': False,
#    'stage3Activated': False,
#    'stage3TargetColor': 'Unknown',
#    'tba_numRobotsHanging': 2,
#    'tba_shieldEnergizedRankingPointFromFoul': False,
#    'techFoulCount': 0,
#    'teleopCellPoints': 42,
#    'teleopCellsBottom': 1,
#    'teleopCellsInner': 3,
#    'teleopCellsOuter': 16,
#    'teleopPoints': 92,
#    'totalPoints': 134})]

# %% [markdown]
# Careful inspection of the output above shows that we successfully created a list of tuples, and that each tuple in the list contains two dictionaries. The problem is that the Pandas `DataFrame` constructor will not handle this input in the manner we would like:

# %%
pd.DataFrame(tuple_list).head(3)
# Out:
#                                                    0  \
# 0  {'actual_time': 1583104716, 'comp_level': 'f',...
# 1  {'actual_time': 1583106972, 'comp_level': 'f',...
# 2  {'actual_time': 1583096632, 'comp_level': 'qf'...
#
#                                                    1
# 0  {'adjustPoints': 0, 'autoCellPoints': 40, 'aut...
# 1  {'adjustPoints': 0, 'autoCellPoints': 38, 'aut...
# 2  {'adjustPoints': 0, 'autoCellPoints': 20, 'aut...

# %% [markdown]
# Pandas created only two columns, one for each dictionary in the tuples. We need a mechanism to extract the key value pairs from both dictionarys and combine them into a single dictionary. Fortunately Python provides a simple syntax for just this operation. Double-astarisk operator to the rescue. Run the code cell below to see how the double-star operator combines two dictionaries into a single dictionary.

# %%
# Dictionary unpacking with the double-asterisk operator
{**{'key1': 1, 'key2': 2}, **{'key3': 3, 'key4': 4}}
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %% [markdown]
# The technique used here is called dictionary unpacking. You are probably familiar with using two asterisks for exponentiation, e.g., `3**3 == 27`. But when placed in front of a dictionary, two asterisks instruct Python to extract the key values pairs from the dictionary. Dictionary unpacking with the double-asterisk operator can be used in function call, literal dictionaries (like in the preceeding example) and in list or dictionary comprehensions. [Python Enhancment Proposal (PEP) 448](https://www.python.org/dev/peps/pep-0448/) explains the possible uses of dictionary unpacking. Dictionary unpacking in function calls has been around for many years, but using dictionary unpacking in literal dictionaries and comprehensions has only been allowed since Python version 3.5.
#
# Instead of enclosing the two dictionary expressions in parenthesis to create a tuple, we should enclose them in curly braces and preceed each one with a double-asterisk operator. This will extract the key-value pairs of both dictionaries into a single dictionary.

# %%
dnary_list = [{**dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
               **mtch['score_breakdown']['blue']}
              for mtch in matches]
dnary_list[:5]
# Out:
# [{'actual_time': 1583104716,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m1',
#   'match_number': 1,
#   'post_result_time': 1583105046,
#   'predicted_time': 1583104822,
#   'set_number': 1,
#   'time': 1583103960,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 40,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 2,
#   'autoCellsOuter': 7,
#   'autoInitLinePoints': 15,
#   'autoPoints': 55,
#   'controlPanelPoints': 0,
#   'endgamePoints': 55,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Park',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 26,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 13,
#   'teleopPoints': 81,
#   'totalPoints': 136},
#  {'actual_time': 1583106972,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m2',
#   'match_number': 2,
#   'post_result_time': 1583107173,
#   'predicted_time': 1583107040,
#   'set_number': 1,
#   'time': 1583104380,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 38,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 8,
#   'autoInitLinePoints': 15,
#   'autoPoints': 53,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'None',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 3,
#   'teleopCellPoints': 34,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 17,
#   'teleopPoints': 84,
#   'totalPoints': 137},
#  {'actual_time': 1583096632,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m1',
#   'match_number': 1,
#   'post_result_time': 1583096863,
#   'predicted_time': 1583096645,
#   'set_number': 1,
#   'time': 1583096400,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 20,
#   'autoCellsBottom': 3,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 35,
#   'controlPanelPoints': 0,
#   'endgamePoints': 65,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'None',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 1,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 19,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 1,
#   'teleopCellsOuter': 8,
#   'teleopPoints': 84,
#   'totalPoints': 122},
#  {'actual_time': 1583098723,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m2',
#   'match_number': 2,
#   'post_result_time': 1583098931,
#   'predicted_time': 1583098747,
#   'set_number': 1,
#   'time': 1583098080,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 10,
#   'autoCellsBottom': 1,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 25,
#   'controlPanelPoints': 0,
#   'endgamePoints': 70,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Park',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': False,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 0,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 0,
#   'teleopPoints': 70,
#   'totalPoints': 95},
#  {'actual_time': 1583097215,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf2m1',
#   'match_number': 1,
#   'post_result_time': 1583097388,
#   'predicted_time': 1583097192,
#   'set_number': 2,
#   'time': 1583096820,
#   'winning_alliance': 'blue',
#   'adjustPoints': 0,
#   'autoCellPoints': 24,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 6,
#   'autoInitLinePoints': 15,
#   'autoPoints': 39,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'None',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 42,
#   'teleopCellsBottom': 1,
#   'teleopCellsInner': 3,
#   'teleopCellsOuter': 16,
#   'teleopPoints': 92,
#   'totalPoints': 134}]

# %% [markdown]
# This list converts to a dataframe in the manner we desire. One drawback of this method is that we are only extracting blue alliance data, due to using `['blue']` as one of our dictionary keys in the comprehension statement. We'll address that later.

# %%
pd.DataFrame(dnary_list).head(3)
# Out:
#    actual_time comp_level  event_key              key  match_number  \
# 0   1583104716          f  2020wasno   2020wasno_f1m1             1
# 1   1583106972          f  2020wasno   2020wasno_f1m2             2
# 2   1583096632         qf  2020wasno  2020wasno_qf1m1             1
#
#    post_result_time  predicted_time  set_number        time winning_alliance  \
# 0        1583105046      1583104822           1  1583103960              red
# 1        1583107173      1583107040           1  1583104380              red
# 2        1583096863      1583096645           1  1583096400              red
#
#    ...  stage3TargetColor  tba_numRobotsHanging  \
# 0  ...            Unknown                     2
# 1  ...            Unknown                     2
# 2  ...            Unknown                     2
#
#    tba_shieldEnergizedRankingPointFromFoul  techFoulCount  teleopCellPoints  \
# 0                                    False              0                26
# 1                                    False              3                34
# 2                                    False              0                19
#
#    teleopCellsBottom  teleopCellsInner  teleopCellsOuter  teleopPoints  \
# 0                  0                 0                13            81
# 1                  0                 0                17            84
# 2                  0                 1                 8            84
#
#   totalPoints
# 0         136
# 1         137
# 2         122
#
# [3 rows x 44 columns]

# %% [markdown]
# ## V. Nested Comprehensions
# Next we would like to add columns for the teams in each match. The teams are included in a list that is a few layers down in the JSON data structure. Make sure you understand why the following code works by reviewing the matches JSON data structure that's included earlier in this notebook.

# %%
matches[0]['alliances']['blue']['team_keys']
# Out:
# ['frc2930', 'frc2976', 'frc4918']

# %% [markdown]
# Assuming the teams are listed in order of their station number, we could add three columns to the dataframe, one for each operator station, and insert applicable team number into that column.

# %%
tm_list = [{'station_1': mtch['alliances']['blue']['team_keys'][0],
            'station_2': mtch['alliances']['blue']['team_keys'][1],
            'station_3': mtch['alliances']['blue']['team_keys'][2],
            **dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
            **mtch['score_breakdown']['blue']}
           for mtch in matches]
tm_list[:5]
# Out:
# [{'station_1': 'frc2930',
#   'station_2': 'frc2976',
#   'station_3': 'frc4918',
#   'actual_time': 1583104716,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m1',
#   'match_number': 1,
#   'post_result_time': 1583105046,
#   'predicted_time': 1583104822,
#   'set_number': 1,
#   'time': 1583103960,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 40,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 2,
#   'autoCellsOuter': 7,
#   'autoInitLinePoints': 15,
#   'autoPoints': 55,
#   'controlPanelPoints': 0,
#   'endgamePoints': 55,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Park',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 26,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 13,
#   'teleopPoints': 81,
#   'totalPoints': 136},
#  {'station_1': 'frc2930',
#   'station_2': 'frc2976',
#   'station_3': 'frc4918',
#   'actual_time': 1583106972,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m2',
#   'match_number': 2,
#   'post_result_time': 1583107173,
#   'predicted_time': 1583107040,
#   'set_number': 1,
#   'time': 1583104380,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 38,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 8,
#   'autoInitLinePoints': 15,
#   'autoPoints': 53,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'None',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 3,
#   'teleopCellPoints': 34,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 17,
#   'teleopPoints': 84,
#   'totalPoints': 137},
#  {'station_1': 'frc4512',
#   'station_2': 'frc949',
#   'station_3': 'frc4131',
#   'actual_time': 1583096632,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m1',
#   'match_number': 1,
#   'post_result_time': 1583096863,
#   'predicted_time': 1583096645,
#   'set_number': 1,
#   'time': 1583096400,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 20,
#   'autoCellsBottom': 3,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 35,
#   'controlPanelPoints': 0,
#   'endgamePoints': 65,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'None',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 1,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 19,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 1,
#   'teleopCellsOuter': 8,
#   'teleopPoints': 84,
#   'totalPoints': 122},
#  {'station_1': 'frc4512',
#   'station_2': 'frc949',
#   'station_3': 'frc4131',
#   'actual_time': 1583098723,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m2',
#   'match_number': 2,
#   'post_result_time': 1583098931,
#   'predicted_time': 1583098747,
#   'set_number': 1,
#   'time': 1583098080,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 10,
#   'autoCellsBottom': 1,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 25,
#   'controlPanelPoints': 0,
#   'endgamePoints': 70,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Park',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': False,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 0,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 0,
#   'teleopPoints': 70,
#   'totalPoints': 95},
#  {'station_1': 'frc1318',
#   'station_2': 'frc4513',
#   'station_3': 'frc7461',
#   'actual_time': 1583097215,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf2m1',
#   'match_number': 1,
#   'post_result_time': 1583097388,
#   'predicted_time': 1583097192,
#   'set_number': 2,
#   'time': 1583096820,
#   'winning_alliance': 'blue',
#   'adjustPoints': 0,
#   'autoCellPoints': 24,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 6,
#   'autoInitLinePoints': 15,
#   'autoPoints': 39,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'None',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 42,
#   'teleopCellsBottom': 1,
#   'teleopCellsInner': 3,
#   'teleopCellsOuter': 16,
#   'teleopPoints': 92,
#   'totalPoints': 134}]

# %%
pd.DataFrame(tm_list).head(3)
# Out:
#   station_1 station_2 station_3  actual_time comp_level  event_key  \
# 0   frc2930   frc2976   frc4918   1583104716          f  2020wasno
# 1   frc2930   frc2976   frc4918   1583106972          f  2020wasno
# 2   frc4512    frc949   frc4131   1583096632         qf  2020wasno
#
#                key  match_number  post_result_time  predicted_time  ...  \
# 0   2020wasno_f1m1             1        1583105046      1583104822  ...
# 1   2020wasno_f1m2             2        1583107173      1583107040  ...
# 2  2020wasno_qf1m1             1        1583096863      1583096645  ...
#
#    stage3TargetColor  tba_numRobotsHanging  \
# 0            Unknown                     2
# 1            Unknown                     2
# 2            Unknown                     2
#
#   tba_shieldEnergizedRankingPointFromFoul  techFoulCount  teleopCellPoints  \
# 0                                   False              0                26
# 1                                   False              3                34
# 2                                   False              0                19
#
#    teleopCellsBottom  teleopCellsInner  teleopCellsOuter  teleopPoints  \
# 0                  0                 0                13            81
# 1                  0                 0                17            84
# 2                  0                 1                 8            84
#
#    totalPoints
# 0          136
# 1          137
# 2          122
#
# [3 rows x 47 columns]

# %% [markdown]
# This works, but we can do better. This technique requires us to repeat what is almost the same expression three times, and good programmers don't like to repeat themselves. We are going to convert the three expressions that create the station columns into a single nested dictionary comprehension.
#
# A nested comprehension is a list or dictionary comprehension nested inside another list or dictionary comprehension. Run the following cell to see the output from a dictionary comprehension for the teams.

# %%
{team: team for team in matches[0]['alliances']['blue']['team_keys']}
# Out:
# {'frc2930': 'frc2930', 'frc2976': 'frc2976', 'frc4918': 'frc4918'}

# %% [markdown]
# Ok, that's a start. But the keys need to be 'station_1' through 'station_3', not the team keys. The good news is that Python has a [built in function, `enumerate()`](https://docs.python.org/3/library/functions.html#enumerate) that will help. Run the code cell below to see what the `enumerate()` function does.

# %%
[tpl for tpl in enumerate(matches[0]['alliances']['blue']['team_keys'])]
# Out:
# [(0, 'frc2930'), (1, 'frc2976'), (2, 'frc4918')]

# %% [markdown]
# When we pass a list to `enumerate()`, the function returns two-element tuples. The second element of the tuple is the element from the list, and the first element of the tuple is the order of that element within the list. The `enumerate()` function frequently comes in handy because programmers often have to keep track of where they are in a list when they iterate through it.
#
# Let's add the `enumerate()` function to our comprehension.

# %%
{team_tpl[0]: team_tpl[1]
 for team_tpl in enumerate(matches[0]['alliances']['blue']['team_keys'])}
# Out:
# {0: 'frc2930', 1: 'frc2976', 2: 'frc4918'}

# %% [markdown]
# That's much better, but we want the column names to start with 'Station' and have numbers 1 - 3, not 0 through 2. (If computer programmers had designed FRC, we probably would have station 0 through station 2.) But that's easy to fix. We'll use an f string, which stands for format string. Python f strings have only been around since Python version 3.6, so as of April 2020 when this notebook was drafted, they are not yet addressed in the official Python tutorial. [But you can find a good introduction on the *Real Python* website.](https://realpython.com/python-f-strings/#f-strings-a-new-and-improved-way-to-format-strings-in-python).

# %%
{f'station_{team_tpl[0] + 1}': team_tpl[1]
 for team_tpl in enumerate(matches[0]['alliances']['blue']['team_keys'])}
# Out:
# {'station_1': 'frc2930', 'station_2': 'frc2976', 'station_3': 'frc4918'}

# %% [markdown]
# Python f strings will evaluate expressions placed within curly brackets and insert them into the string.
#
# Now let's add the nested team comprehension to the outer list comprehension. We need to use the double-asterisk operator in front of the nested dictionary comprehension to unpack it.

# %%
tm_list2 = [{**{f'station_{tm_tpl[0] + 1}': tm_tpl[1] for tm_tpl
                in enumerate(mtch['alliances']['blue']['team_keys'])},
             'dq': mtch['alliances']['blue']['dq_team_keys'],
             **dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
             **mtch['score_breakdown']['blue']}
            for mtch in matches]
tm_list2[:5]
# Out:
# [{'station_1': 'frc2930',
#   'station_2': 'frc2976',
#   'station_3': 'frc4918',
#   'dq': [],
#   'actual_time': 1583104716,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m1',
#   'match_number': 1,
#   'post_result_time': 1583105046,
#   'predicted_time': 1583104822,
#   'set_number': 1,
#   'time': 1583103960,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 40,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 2,
#   'autoCellsOuter': 7,
#   'autoInitLinePoints': 15,
#   'autoPoints': 55,
#   'controlPanelPoints': 0,
#   'endgamePoints': 55,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Park',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 26,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 13,
#   'teleopPoints': 81,
#   'totalPoints': 136},
#  {'station_1': 'frc2930',
#   'station_2': 'frc2976',
#   'station_3': 'frc4918',
#   'dq': [],
#   'actual_time': 1583106972,
#   'comp_level': 'f',
#   'event_key': '2020wasno',
#   'key': '2020wasno_f1m2',
#   'match_number': 2,
#   'post_result_time': 1583107173,
#   'predicted_time': 1583107040,
#   'set_number': 1,
#   'time': 1583104380,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 38,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 8,
#   'autoInitLinePoints': 15,
#   'autoPoints': 53,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'None',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 3,
#   'teleopCellPoints': 34,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 17,
#   'teleopPoints': 84,
#   'totalPoints': 137},
#  {'station_1': 'frc4512',
#   'station_2': 'frc949',
#   'station_3': 'frc4131',
#   'dq': [],
#   'actual_time': 1583096632,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m1',
#   'match_number': 1,
#   'post_result_time': 1583096863,
#   'predicted_time': 1583096645,
#   'set_number': 1,
#   'time': 1583096400,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 20,
#   'autoCellsBottom': 3,
#   'autoCellsInner': 1,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 35,
#   'controlPanelPoints': 0,
#   'endgamePoints': 65,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'None',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 1,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 19,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 1,
#   'teleopCellsOuter': 8,
#   'teleopPoints': 84,
#   'totalPoints': 122},
#  {'station_1': 'frc4512',
#   'station_2': 'frc949',
#   'station_3': 'frc4131',
#   'dq': [],
#   'actual_time': 1583098723,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf1m2',
#   'match_number': 2,
#   'post_result_time': 1583098931,
#   'predicted_time': 1583098747,
#   'set_number': 1,
#   'time': 1583098080,
#   'winning_alliance': 'red',
#   'adjustPoints': 0,
#   'autoCellPoints': 10,
#   'autoCellsBottom': 1,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 2,
#   'autoInitLinePoints': 15,
#   'autoPoints': 25,
#   'controlPanelPoints': 0,
#   'endgamePoints': 70,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Park',
#   'endgameRobot3': 'Hang',
#   'endgameRungIsLevel': 'IsLevel',
#   'foulCount': 0,
#   'foulPoints': 0,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': False,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 0,
#   'teleopCellsBottom': 0,
#   'teleopCellsInner': 0,
#   'teleopCellsOuter': 0,
#   'teleopPoints': 70,
#   'totalPoints': 95},
#  {'station_1': 'frc1318',
#   'station_2': 'frc4513',
#   'station_3': 'frc7461',
#   'dq': [],
#   'actual_time': 1583097215,
#   'comp_level': 'qf',
#   'event_key': '2020wasno',
#   'key': '2020wasno_qf2m1',
#   'match_number': 1,
#   'post_result_time': 1583097388,
#   'predicted_time': 1583097192,
#   'set_number': 2,
#   'time': 1583096820,
#   'winning_alliance': 'blue',
#   'adjustPoints': 0,
#   'autoCellPoints': 24,
#   'autoCellsBottom': 0,
#   'autoCellsInner': 0,
#   'autoCellsOuter': 6,
#   'autoInitLinePoints': 15,
#   'autoPoints': 39,
#   'controlPanelPoints': 0,
#   'endgamePoints': 50,
#   'endgameRobot1': 'Hang',
#   'endgameRobot2': 'Hang',
#   'endgameRobot3': 'None',
#   'endgameRungIsLevel': 'NotLevel',
#   'foulCount': 0,
#   'foulPoints': 3,
#   'initLineRobot1': 'Exited',
#   'initLineRobot2': 'Exited',
#   'initLineRobot3': 'Exited',
#   'rp': 0,
#   'shieldEnergizedRankingPoint': False,
#   'shieldOperationalRankingPoint': False,
#   'stage1Activated': True,
#   'stage2Activated': False,
#   'stage3Activated': False,
#   'stage3TargetColor': 'Unknown',
#   'tba_numRobotsHanging': 2,
#   'tba_shieldEnergizedRankingPointFromFoul': False,
#   'techFoulCount': 0,
#   'teleopCellPoints': 42,
#   'teleopCellsBottom': 1,
#   'teleopCellsInner': 3,
#   'teleopCellsOuter': 16,
#   'teleopPoints': 92,
#   'totalPoints': 134}]

# %%
pd.DataFrame(tm_list2).head(3)
# Out:
#   station_1 station_2 station_3  dq  actual_time comp_level  event_key  \
# 0   frc2930   frc2976   frc4918  []   1583104716          f  2020wasno
# 1   frc2930   frc2976   frc4918  []   1583106972          f  2020wasno
# 2   frc4512    frc949   frc4131  []   1583096632         qf  2020wasno
#
#                key  match_number  post_result_time  ...  stage3TargetColor  \
# 0   2020wasno_f1m1             1        1583105046  ...            Unknown
# 1   2020wasno_f1m2             2        1583107173  ...            Unknown
# 2  2020wasno_qf1m1             1        1583096863  ...            Unknown
#
#    tba_numRobotsHanging  tba_shieldEnergizedRankingPointFromFoul  \
# 0                     2                                    False
# 1                     2                                    False
# 2                     2                                    False
#
#   techFoulCount  teleopCellPoints  teleopCellsBottom  teleopCellsInner  \
# 0             0                26                  0                 0
# 1             3                34                  0                 0
# 2             0                19                  0                 1
#
#    teleopCellsOuter  teleopPoints  totalPoints
# 0                13            81          136
# 1                17            84          137
# 2                 8            84          122
#
# [3 rows x 48 columns]

# %% [markdown]
# It works!

# %% [markdown]
# ## VI. Including *if* Statements in Comprehensions
# Take a look at this line in the matches JSON:
# ```json
# 'alliances': {'blue': {'dq_team_keys': [], ...
# ```
# If a team were disqualified durign a match, the team key would be included in the list following *dq_team_keys*. If more than one team was disqualified, there would be more than one team in this list. We need to make a decision on what we want to do with this information. There are several different choices we could make.
# 1. We could ignore it, and just not include information on disqualified teams in the dataframe. There is nothing wrong with this choice. Teams are rarely disqualified and every dataframe does not need to contain all available data.
# 2. We could add a single column to the dataframe with the dq information as a string, with no extra processing. For matches where no team is disqualified (most matches), the column will contain the value '[]'. If a single team is disqualified, the column will contain '[frcXXXX]'. This is an easy option and the user of the data frame can easily see if a team is disqualified, but they will have to write special code to interpret the contents of this column.
# 3. We could add an extra column for every team in the list. If no teams are disqualified, then there is no disqualified column. If there is a match where two teams are disqualified, then there are two columns for disqualified teams. The problems with this approach is that the dataframe will have different numbers of columns for different events, and the user of the dataframe will have to test of the existance of columns. This is not a good approach.
#
# The author prefers a modified version of option #2 that looks like this:

# %%
[{'teams_dq': mtch['alliances']['blue']['dq_team_keys']}
 if mtch['alliances']['blue']['dq_team_keys'] else None
 for mtch in matches][:5]
# Out:
# [None, None, None, None, None]

# %% [markdown]
# This method uses a one-line `if` statement to check if the *dq_team_keys* list contains any data. If it's empty, we insert the Python value `None` into the column. Otherwise, we insert the teams into the column as a string. It takes advantage of a couple Python-isms.
# * When evalauted as a Boolean, an empty string converts to `False`. The value `mtch['alliances']['blue']['dq_team_keys']` that occurrs after the `if` statement will evaluate to True if one or more teams were disqualified, and `False` otherwise.
# * Consequently, if no teams were disqualified, the `None` value in the `else` clause will be returned. Otherwise the column will contain a string that identifies the disqualified teams.
#
# We can use the exact same technique for including surrogate teams. Also, did you notice that we had to type the string 'blue' twice in the cell above? And it occurred three times in the cell before that? Let's replace it with a variable that contains the string 'blue'. Putting all of that together looks like this:

# %%
alli = 'blue'

mtch_lst = [{**{f'station_{tm_tpl[0] + 1}': tm_tpl[1] for tm_tpl
                in enumerate(mtch['alliances'][alli]['team_keys'])},
             
            'teams_dq': mtch['alliances'][alli]['dq_team_keys']
                if mtch['alliances'][alli]['dq_team_keys'] else None,
             
            'teams_surrogate': mtch['alliances'][alli]['surrogate_team_keys']
                if mtch['alliances'][alli]['surrogate_team_keys'] else None,
             
            **dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
             
            **mtch['score_breakdown'][alli]}
            for mtch in matches]

pd.DataFrame(mtch_lst).head(3)
# Out:
#   station_1 station_2 station_3 teams_dq teams_surrogate  actual_time  \
# 0   frc2930   frc2976   frc4918     None            None   1583104716
# 1   frc2930   frc2976   frc4918     None            None   1583106972
# 2   frc4512    frc949   frc4131     None            None   1583096632
#
#   comp_level  event_key              key  match_number  ...  \
# 0          f  2020wasno   2020wasno_f1m1             1  ...
# 1          f  2020wasno   2020wasno_f1m2             2  ...
# 2         qf  2020wasno  2020wasno_qf1m1             1  ...
#
#    stage3TargetColor  tba_numRobotsHanging  \
# 0            Unknown                     2
# 1            Unknown                     2
# 2            Unknown                     2
#
#    tba_shieldEnergizedRankingPointFromFoul  techFoulCount teleopCellPoints  \
# 0                                    False              0               26
# 1                                    False              3               34
# 2                                    False              0               19
#
#    teleopCellsBottom  teleopCellsInner  teleopCellsOuter  teleopPoints  \
# 0                  0                 0                13            81
# 1                  0                 0                17            84
# 2                  0                 1                 8            84
#
#    totalPoints
# 0          136
# 1          137
# 2          122
#
# [3 rows x 49 columns]

# %% [markdown]
# ## VII. Final Touches
# There are two pieces of data that are still missing from this dataframe: the alliance score and the video links. We're going to ignore the video links, but the alliance score is easy to add.

# %%
alli = 'blue'

mtch_lst2 = [{# Alliance Information
             'alliance_score': mtch['alliances'][alli]['score'], 
    
             # Extract Team Numbers
             **{f'station_{tm_tpl[0] + 1}': tm_tpl[1] for tm_tpl
                 in enumerate(mtch['alliances'][alli]['team_keys'])},
             
             # Disqualified and Surrogate Teams
             'teams_dq': mtch['alliances'][alli]['dq_team_keys']
                 if mtch['alliances'][alli]['dq_team_keys'] else None,
             
             # Match Description
             'teams_surrogate': mtch['alliances'][alli]['surrogate_team_keys']
                 if mtch['alliances'][alli]['surrogate_team_keys'] else None,
            
             # Detailed Match Scores
             **dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)), mtch.items())),
             
             **mtch['score_breakdown'][alli]}
             for mtch in matches]

pd.DataFrame(mtch_lst2).head(3)
# Out:
#    alliance_score station_1 station_2 station_3 teams_dq teams_surrogate  \
# 0             136   frc2930   frc2976   frc4918     None            None
# 1             137   frc2930   frc2976   frc4918     None            None
# 2             122   frc4512    frc949   frc4131     None            None
#
#    actual_time comp_level  event_key              key  ...  stage3TargetColor  \
# 0   1583104716          f  2020wasno   2020wasno_f1m1  ...            Unknown
# 1   1583106972          f  2020wasno   2020wasno_f1m2  ...            Unknown
# 2   1583096632         qf  2020wasno  2020wasno_qf1m1  ...            Unknown
#
#    tba_numRobotsHanging  tba_shieldEnergizedRankingPointFromFoul  \
# 0                     2                                    False
# 1                     2                                    False
# 2                     2                                    False
#
#    techFoulCount  teleopCellPoints teleopCellsBottom  teleopCellsInner  \
# 0              0                26                 0                 0
# 1              3                34                 0                 0
# 2              0                19                 0                 1
#
#    teleopCellsOuter  teleopPoints  totalPoints
# 0                13            81          136
# 1                17            84          137
# 2                 8            84          122
#
# [3 rows x 50 columns]

# %% [markdown]
# There is still one big glaring problem. This dataframe only contains detailed scores for the blue alliance. To fix that, we'll run the statement twice, creating one dataframe for blue and one for red, and then we'll combine the dataframes.

# %%
alliances = ['red', 'blue']
frames = []
for alli in alliances:
    frames.append(pd.DataFrame(
        [{# Alliance Information
            'alliance': alli,
            'alliance_score': mtch['alliances'][alli]['score'], 

            # Extract Team Numbers
            **{f'station_{tm_tpl[0] + 1}': tm_tpl[1] for tm_tpl
                    in enumerate(mtch['alliances'][alli]['team_keys'])},

            # Disqualified and Surrogate Teams
            'teams_dq': mtch['alliances'][alli]['dq_team_keys']
                    if mtch['alliances'][alli]['dq_team_keys'] else None,

            # Match Description
            'teams_surrogate': mtch['alliances'][alli]['surrogate_team_keys']
                    if mtch['alliances'][alli]['surrogate_team_keys'] else None,

            # Detailed Match Scores
            **dict(filter(lambda tpl: not isinstance(tpl[1], (dict, list)),
                    mtch.items())),

            **mtch['score_breakdown'][alli]}
         for mtch in matches]))
match_scores = pd.concat(frames)
match_scores.head()
# Out:
#   alliance  alliance_score station_1 station_2 station_3 teams_dq  \
# 0      red             148   frc4911   frc2910   frc4173     None
# 1      red             163   frc4911   frc2910   frc4173     None
# 2      red             193   frc4911   frc2910   frc4173     None
# 3      red             140   frc4911   frc2910   frc4173     None
# 4      red              89   frc4089   frc4915   frc4309     None
#
#   teams_surrogate  actual_time comp_level  event_key  ... stage3TargetColor  \
# 0            None   1583104716          f  2020wasno  ...           Unknown
# 1            None   1583106972          f  2020wasno  ...           Unknown
# 2            None   1583096632         qf  2020wasno  ...           Unknown
# 3            None   1583098723         qf  2020wasno  ...           Unknown
# 4            None   1583097215         qf  2020wasno  ...           Unknown
#
#    tba_numRobotsHanging  tba_shieldEnergizedRankingPointFromFoul  \
# 0                     1                                    False
# 1                     1                                    False
# 2                     2                                    False
# 3                     1                                    False
# 4                     0                                    False
#
#    techFoulCount  teleopCellPoints  teleopCellsBottom teleopCellsInner  \
# 0              0                56                  0                4
# 1              0                43                  0                3
# 2              0                78                  0                8
# 3              0                38                  0                2
# 4              0                42                  0                2
#
#    teleopCellsOuter  teleopPoints  totalPoints
# 0                22           101          148
# 1                17            83          163
# 2                27           143          193
# 3                16            83          140
# 4                18            52           89
#
# [5 rows x 51 columns]

# %% [markdown]
# We made several changes in this most recent iteration of the list comprehension:
# 1. We added a column to identify the alliance: `'alliance': alli,`
# 2. We placed the list comprehension in a `for` loop so it will be run twice, once for the red alliance and once for the blue.
# 3. We put the two resulting dataframes in a list.
# 4. We called the Pandas `concat` function to combine the two dataframes into a single dataframe.

# %% [markdown]
# ## VIII. The Next Step.
# This dataframe still needs some work. The columns with times are incomprehensible, the order of the dataframe makes little sense, and integer indices (numbers at far left of the dataframe) are arbitrary. We will use Pandas tools to make those fixes [in the next notebook.](pj01_nb04_tba_pandas.ibynb)

# %% [markdown]
# [Table of Contents](../../index.ipynb)
